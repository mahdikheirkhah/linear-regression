# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X = np.arange(1,21).reshape(10,-1)
y = np.arange(1,11)

# %% [markdown]
# 1. Split the data using `train_test_split` with `shuffle=False`. The test set represents 20% of the total size of the dataset. Print X_train, y_train, X_test, y_test.

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.2)

print("------------------------------ train ------------------------------")
print(f"X_train is: {X_train}\n")
print(f"y_train is: {y_train}\n")

print("------------------------------ test ------------------------------")
print(f"X_train is: {X_test}\n")
print(f"y_train is: {y_test}\n")
# Out:
# ------------------------------ train ------------------------------
# X_train is: [[17 18]
#  [ 1  2]
#  [11 12]
#  [ 3  4]
#  [ 7  8]
#  [ 9 10]
#  [19 20]
#  [13 14]]
#
# y_train is: [[15 16]
#  [ 5  6]]
#
# ------------------------------ test ------------------------------
# X_train is: [ 9  1  6  2  4  5 10  7]
#
# y_train is: [8 3]
